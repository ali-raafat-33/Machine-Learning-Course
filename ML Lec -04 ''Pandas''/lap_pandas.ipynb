# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/diabetes_dataset.csv")
df.head(10)

# %%
df.columns.tolist()

# %%
df=df.drop('location',axis=1)
df.columns.tolist()

# %%
df

# %%
df.sample(5)

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.drop_duplicates()

# %%
(df.query('age < 10').shape[0]/df.query('age < 80').shape[0])*100
